# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# !cd /content/drive/MyDrive/기계데이터경진대회

# %%
op_csv = pd.read_csv('/content/drive/MyDrive/기계데이터경진대회/kimm.csv', header=None, names=['value','nan'])
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (12001) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,2,1)
plt.plot(test1)
plt.subplot(3,2,2)
plt.plot(test2)
plt.subplot(3,2,3)
plt.plot(test3)
plt.subplot(3,2,4)
plt.plot(test4)
plt.subplot(3,2,5)
plt.plot(test5)
# kimm[1]의 주기 = 45

# %%
kimm = pd.read_csv('/content/drive/MyDrive/기계데이터경진대회/kimm.csv', header=None)
del kimm[0]
kimm
kimm = kimm.iloc[200]
kimm_op

# plt.subplot(2,3,1)
kimm_op = kimm[:45]
plt.figure(figsize=(10,5))
plt.plot(kimm_op)

# plt.subplot(2,3,1)
kimm_op_series = kimm[:1000]
plt.figure(figsize=(30,10))
plt.plot(kimm_op_series)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (12001) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
kimm = pd.read_csv('/content/drive/MyDrive/기계데이터경진대회/kimm.csv', header=None)
del kimm[0]
kimm
kimm_no = kimm.iloc[300]
kimm_no

# plt.subplot(2,3,1)
kimm_no = kimm_no[:1000]
plt.figure(figsize=(20,10))
plt.plot(kimm_no)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (12001) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# kimm 주기 68
vib = pd.read_csv('/content/drive/MyDrive/기계데이터경진대회/vibration.csv', header=None,skiprows=1)
vib
del vib[0]
vib
vib = vib.iloc[150]
vib_op

# plt.subplot(2,3,1)
vib_op = vib_op[:500]
plt.figure(figsize=(30,5))
plt.plot(vib_op)



# plt.subplot(2,3,1)
vib_op_series = vib_op[:68]
plt.figure(figsize=(10,5))
plt.plot(vib_op_series)

# plt.subplot(2,3,1)
vib_op_series1 = vib_op[68:136]
plt.figure(figsize=(10,5))
plt.plot(vib_op_series1)

# plt.subplot(2,3,1)
vib_op_series1 = vib_op[136:204]
plt.figure(figsize=(10,5))
plt.plot(vib_op_series1)

# plt.subplot(2,3,1)
vib_op_series1 = vib_op[204:272]
plt.figure(figsize=(10,5))
plt.plot(vib_op_series1)

# %%
vib = pd.read_csv('/content/drive/MyDrive/기계데이터경진대회/vibration.csv', header=None,skiprows=1)
vib
del vib[0]
vib
vib_no = vib.iloc[300]
vib_no

# plt.subplot(2,3,1)
vib_no = vib_no[:1000]
plt.figure(figsize=(30,5))
plt.plot(vib_no)
